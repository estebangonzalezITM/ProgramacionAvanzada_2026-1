# %% [markdown]
# # **1. Funciones**
#
# ## **1.1 Declaración de funciones**
#
#
# En Python se utiliza la palabra reservada ` def ` para definir una función. La sintaxis es la siguiente:
#
# <br>
#
#  **def** _nombreDeLaFuncion_ **(** $parametro_1, parametro_2, ..., parametro_n$ **):**
#
# A continuación un ejemplo:

# %%
def imprimirMensaje(nombre="Estudiante"):
    '''
    Docstring.
    Procedimiento que imprime un mensaje utilizando un valor de entrada.

    INPUT:
        nombre: str
    OUTPUT:
        None
    '''
    if(type(nombre) != str): #validamos que el argumento <nombre> sea de tipo string
        print("Error, el parámetro de entrada debe ser un str.")
    else:
        print(f"Hola {nombre}. Bienvenido al curso")

# %%
print(imprimirMensaje('Esteban'))
# Out:
# Hola Esteban. Bienvenido al curso
# None

# %%
print(imprimirMensaje())
# Out:
# Hola Estudiante. Bienvenido al curso
# None

# %%
 # El parámetro de la función es *nombre*. *Estudiante* sería el valor por defecto del parámetro,
 # El valor por defecto es opcional (pero recomendado), y se usa cuando no se le entrega un valor
 # a la función.

# %%
help(imprimirMensaje)
# imprimirMensaje?
# Out:
# Help on function imprimirMensaje in module __main__:
#
# imprimirMensaje(nombre='Estudiante')
#     Docstring.
#     Procedimiento que imprime un mensaje utilizando un valor de entrada.
#
#     INPUT:
#         nombre: str
#     OUTPUT:
#         None

# %%
#llamado a la funcion
s = 'Miguel'

imprimirMensaje(s)
# Out:
# Hola Miguel. Bienvenido al curso

# %%
imprimirMensaje('Esteban')
# Out:
# Hola Esteban. Bienvenido al curso

# %%
imprimirMensaje(98.86)
# Out:
# Error, el parámetro de entrada debe ser un str.

# %% [markdown]
# ## **1.2 Parámetros y argumentos**
#
# Definiciones:
#
# 1. **Parámetros**: Variables de la definición de la función y a las que son asignadas un valor al momento de llamar la función.
# 2. **Argumentos**: Valores que son asignados a los parámetros de la función al momento del llamado.
#
# El número de parámetros que puede recibir una función es arbitrario, es decir, tantos como se necesiten.

# %%
def miFuncion(a,b,c,d): # Parametros de la funcion: a, b, c, d (notar que no tienen valores por defecto)
    '''
    Función que recibe cuatro parámetros y retorna el cuadrado del producto de ellos
    '''
    f = (a*b*c*d)

    return f**2  # *return* es la instrucción que permite que la función "entregue" un resultado al programa que la llamó.

a = miFuncion(1,2,3,1)
print(a)
# Out:
# 36

# %%
resultado = miFuncion(1,2,3,1) # argumentos de la funcion
print(resultado)
# Out:
# 36

# %% [markdown]
# * Diferencia entre print vs return

# %%
def miFuncion(a,b,c,d): # Parametros de la funcion: a, b, c, d (notar que no tienen valores por defecto)
    '''
    Función que recibe cuatro parámetros y retorna el cuadrado del producto de ellos
    '''
    f = (a*b*c*d)

    print (f**2)  # *return* es la instrucción que permite que la función "entregue" un resultado al programa que la llamó.

a = miFuncion(1,2,3,1)
print(a)
type(a)
# Out:
# 36
# None
# NoneType

# %% [markdown]
# * Los parámetros y argumentos son **Variables Locales**:
#
# En el ejemplo, las variables `a`, `b`, `c`, `d` y `f` son locales a la función. Nacen cuando la función empieza a ejecutarse y mueren (se borran de la memoria) en cuanto la función llega al return o termina.

# %%
f = 'gato'
a = True

def miFuncion(a,b,c,d): # Parametros de la funcion: a, b, c, d (notar que no tienen valores por defecto)
    f = (a*b*c*d)
    return f**2  # *return* es la instrucción que permite que la función "entregue" un resultado al programa que la llamó.

resultado = miFuncion(1,2,3,1)
print(resultado)
print(f,',',a)
# Out:
# 36
# gato , True

# %% [markdown]
# ## **1.3 Parámetros por defecto**
#
# Python permite la asignación de valores por defecto a los parámetros de una función. Esto es, es posible asignar un valor por defecto a uno o varios parámetros de la función, de tal forma que si el usuario no ingresa un argumento para un parámetro, se asigna el valor por defecto a este último.

# %%
# ¿Qué pasa si no tenemos valores por defecto?
def miFuncion(a,b,c,d):
    f = (a*b*c*d)
    return f**2

miFuncion(1,2,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_568/3436078415.py in <cell line: 0>()
#       4     return f**2
#       5
# ----> 6 miFuncion(1,2,1)
#
# TypeError: miFuncion() missing 1 required positional argument: 'd'

# %%
def miFuncion(a,b=1,c=1,d=2): #parametros de la funcion: a, b, c, d
    '''
    Función que recibe cuatro parámetros y retorna el cuadrado producto de ellos
    '''
    f = (a*b*c*d)
    return f**2

resultado = miFuncion(2,1) #argumentos de la funcion
print(resultado)
# Out:
# 16

# %%
def y(v0, t, g=9.8): #valor por defecto para el parámetro g
    y = v0*t - 0.5*g*t**2
    return y
print(y(10,1))
y(10,1,9.78)
# Out:
# 5.1
# 5.11

# %%
for t in range(1,5):
    print("tiempo: "+str(t)+" s ; y = "+str(y(10,t))+' m')
# Out:
# tiempo: 1 s ; y = 5.1 m
# tiempo: 2 s ; y = 0.3999999999999986 m
# tiempo: 3 s ; y = -14.100000000000001 m
# tiempo: 4 s ; y = -38.400000000000006 m

# %%
for t1 in range(1,5):
    print("tiempo: "+str(t1), y(t = t1, v0 = 10),' m') #llamada a la funcion utilizando el valor por defecto para g
# Out:
# tiempo: 1 5.1  m
# tiempo: 2 0.3999999999999986  m
# tiempo: 3 -14.100000000000001  m
# tiempo: 4 -38.400000000000006  m

# %% [markdown]
# ## **1.4 Uso de**  `*args` **y** `**kwargs`
#
# ¿Para qué se usan? En realidad no tienes porque usar los nombres `args` o `kwargs`, ya que se trata de una mera convención entre programadores.
#
# Sin embargo lo que si que tienes que usar es el asterisco simple `*` o doble `**`. Es decir, podrías escribir `*datos` y `**numeros` y el resultado será el mismo.
#
# https://python-intermedio.readthedocs.io/es/latest/args_and_kwargs.html

# %%
def test_var_args(*argv):
    for i in argv:
        print("argumentos de *argv:", i)
    print(argv)
    print(type(argv))

# %%
#test_var_args('python', 'foo', 'bar')
test_var_args(1,10,100,1,20,5,1,20,5)
# Out:
# argumentos de *argv: 1
# argumentos de *argv: 10
# argumentos de *argv: 100
# argumentos de *argv: 1
# argumentos de *argv: 20
# argumentos de *argv: 5
# argumentos de *argv: 1
# argumentos de *argv: 20
# argumentos de *argv: 5
# (1, 10, 100, 1, 20, 5, 1, 20, 5)
# <class 'tuple'>

# %% [markdown]
# * Como acabamos de ver, los datos guardados con `*args` se guardan como una tupla

# %% [markdown]
# * Puede usarse para guardar datos cuando no se sabe cuantos se van a recibir, o cuando hay datos opcionales:

# %%
def test_args(f_arg=0, *argv):
    print("primer argumento normal:", f_arg)
    print(f_arg)
    print(type(f_arg))
    print(f'los demás argumentos{argv}')
    print(type(argv))

#test_args('python', 'foo', 'bar')
test_args(1,10,100)
# Out:
# primer argumento normal: 1
# 1
# <class 'int'>
# los demás argumentos(10, 100)
# <class 'tuple'>

# %%
def test_args2(*datos):
    suma = sum(datos)
    print (f'Los datos ingresados son {datos}')
    return 'Los datos ingresados suman '+ str(suma)

test_args2(1,10,100)
# Out:
# Los datos ingresados son (1, 10, 100)
# 'Los datos ingresados suman 111'

# %% [markdown]
# La diferencia fundamental entre `*args` y `**kwargs` radica en cómo empaquetan los datos que sobran al llamar a una función.
#
# Si `*args` es una "bolsa" de valores, `**kwargs` es un "contenedor etiquetado", que permite pasar argumentos con un nombre asociado (llave=valor).
#
# `**args` guarda los datos en una tupla y `**kwargs` en un diccionario

# %%
def test_kwargs(**kwargs):
    print(kwargs)
    print(type(kwargs))

test_kwargs(nombre="Covadonga", apellido = "Verdugo", edad1 = 37 )
#           llave1=valor1     ,    llave2=valor2
# Out:
# {'nombre': 'Covadonga', 'apellido': 'Verdugo', 'edad1': 37}
# <class 'dict'>

# %%
def Hello(**world):
    print(world)
    print(type(world))

Hello(e1="Hola", e2 = "Mundo", e3 = 2026)
# Out:
# {'e1': 'Hola', 'e2': 'Mundo', 'e3': 2026}
# <class 'dict'>

# %% [markdown]
# * **NOTA:** En el caso `**kwargs` python asume que se está creando una variable, por tanto la llave solo debe contener caracteres alfanuméricos y guiones bajos, ya que en esta sintaxis (y no comenzar con un numero)

# %%
Hello(e1="Hola", e2 = "Mundo", 3 = 'tres')
# Out:
#   File "/tmp/ipykernel_185/175871023.py", line 1
#     Hello(e1="Hola", e2 = "Mundo", 3 = 'tres')
#                                    ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# ## ¿Para qué se usan?
#
# `*args` es útil para funciones matemáticas que reciben muchos números o para imprimir mensajes variables.
#
# `**kwargs` es el estándar en librerías de visualización (como Matplotlib) o de Machine Learning (como Scikit-Learn). Se usa para pasar configuraciones y parámetros (como el color, el tamaño de la fuente, el número de neuronas, etc.) de forma opcional.

# %% [markdown]
# ## **1.5 Valores de retorno**
#
# Una función puede retornar un valor. En cuyo caso utilizamos la palabra reservada __return__.
#
# Sintaxis:
#
# __return__ objeto_a_retornar

# %%
def cuad(x):
    return x**2 #se retorna el valor x al cuadrado

a = 15

Respuesta = cuad(a)

print(Respuesta)
print(type(Respuesta))
print(cuad(a))
Respuesta/2
# Out:
# 225
# <class 'int'>
# 225
# 112.5

# %% [markdown]
# * Si solo se imprime (`print`), la función muestra el resultado, pero tú se puede usar ese número para otra operación matemática fuera de ella.
#
# * Si se usa `return`, la función "entrega" resultado para que puedas guardarlo en una variable y seguir trabajando con él.

# %%
def cuad2(x):
  print(x**2)

Rta = cuad2(a)
print(type(Rta))
print(Rta)
Rta/2
# Out:
# 225
# <class 'NoneType'>
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_185/1391296476.py in <cell line: 0>()
#       5 print(type(Rta))
#       6 print(Rta)
# ----> 7 Rta/2
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %% [markdown]
# * Una función con valor de retorno, equivale en el momento del llamado, al tipo de dato que retorna. Es decir, una función que devuelve o retorna un valor, soporta todas las operaciones del tipo de dato que retorna.

# %%
import math

x = 4
y = math.sqrt(cuad(x) + 9) #estamos utilizando cuad(x) como un flotante

print(y)
# Out:
# 5.0

# %% [markdown]
# * Desempaquedatos extendido de iterables

# %%
def ejemplo(*args):
    num1, num2, *_ = args    # Esta línea asigna los dos primeros por posición a las variables num1 y num2. Todo lo demás se "desecha" (se almacenan en una tupla)
    suma = num1 + num2
    print(f'Los números ingresados son {args}')
    return suma

ejemplo(1,2.0,3,4,5,6)
    #num1, num2, *_ = args es equivalente a hacer: num1 = args[1] y num2 = args[2]
# Out:
# Los números ingresados son (1, 2.0, 3, 4, 5, 6)
# 3.0

# %%
def ejemplo(*args):
    num1, num2, *_ = args    # Esta línea asigna los dos primeros por posición a las variables num1 y num2. Todo lo demás se "desecha" (se almacenan en una tupla)
    print(f'Los números ingresados son {args}')
    return num1 + num2

ejemplo(1,2.0,3,4,5,6)
# Out:
# Los números ingresados son (1, 2.0, 3, 4, 5, 6)
# 3.0

# %% [markdown]
# ## **1.6 Múltiples valores de retorno**
#
# En caso de que una funcion deba retornar más de un valor, podemos:
#
# __1.6.1. Agregar los elementos__ a retornar en una estructura de datos.
#
# __1.6.2. Retornar los elementos separados por coma (,)__: En este caso, Python se encarga de agregar automáticamente los elementos en una tupla.

# %%
## definir una función que reciba dos números como parámetros, debemos
## retornar la suma, la resta, el producto y la división de los
## dos números

def ejemplo1(*args):
    num1, num2, *_ = args
    suma = num1+num2
    resta = num1-num2
    producto = num1*num2
    division = num1/num2
    print(f'Los números ingresados son {args}')

    return suma, resta, producto, division

ejm = ejemplo1(1,2,3,4,5,6)
print(f'ejm_tupla = {ejm}')
print(type(ejm))
# Out:
# Los números ingresados son (1, 2, 3, 4, 5, 6)
# ejm_tupla = (3, -1, 2, 0.5)
# <class 'tuple'>

# %% [markdown]
# __1.6.3. También se puede pedir (manualmente) que retorne una lista [,]__:

# %%
def ejemplo2(*args):
    num1, num2, *_ = args
    suma = num1+num2
    resta = num1-num2
    producto = num1*num2
    division = num1/num2
    print(f'Los números ingresados son {args}')

    return [suma, resta, producto, division]

ejm = ejemplo2(1,2,3,4,5,6)
print(f'ejm_lista = {ejm}')
print(type(ejm))
# Out:
# Los números ingresados son (1, 2, 3, 4, 5, 6)
# ejm_lista = [3, -1, 2, 0.5]
# <class 'list'>

# %% [markdown]
# __1.6.4. También se puede pedir (manualmente) que retorne un diccionario {:}__:

# %%
def ejemplo3(*args):
    num1, num2, *_ = args
    suma = num1+num2
    resta = num1-num2
    producto = num1*num2
    division = num1/num2
    print(f'Los números ingresados son {args}')

    return {"s":suma, "r":resta, "p":producto, "div":division}

ejm = ejemplo3(1,2,3,4,5,6)
print(f'ejm_lista = {ejm}')
print(type(ejm))
# Out:
# Los números ingresados son (1, 2, 3, 4, 5, 6)
# ejm_lista = {'s': 3, 'r': -1, 'p': 2, 'div': 0.5}
# <class 'dict'>

# %%
a = 3

L = ejemplo3(1,a)
print(type(L))
print(L)
print(L["r"])
# Out:
# Los números ingresados son (1, 3)
# <class 'dict'>
# {'s': 4, 'r': -2, 'p': 3, 'div': 0.3333333333333333}
# -2

# %% [markdown]
# __1.6.5. También se puede usar con **kwargs__:

# %%
## definir una función que reciba dos números como parámetros, debemos
## retornar la suma, la resta, el producto y la división de los
## dos números

def ejemplokwargs(**kwargs):
    num1 = kwargs['e1']      # Obliga a que el usuario entregue un argumento llamado exactamente e1
    num2 = kwargs['e2']      # Obliga a que el usuario entregue un argumento llamado exactamente e1
    suma = num1+num2
    resta = num1-num2
    producto = num1*num2
    division = num1/num2
    print(f'El diccionario ingresado es {kwargs}')
    lista = [suma, resta, producto, division]

    return lista

ejm = ejemplokwargs(e1=1,e2=2,e3=2,llave='52')

print(f'ejm_lista = {ejm}')
#print(type(ejm))
# Out:
# El diccionario ingresado es {'e1': 1, 'e2': 2, 'e3': 2, 'llave': '52'}
# ejm_lista = [3, -1, 2, 0.5]

# %% [markdown]
# ## **1.7 Los elementos retornados se pueden almacenar de manera independiente**

# %%
a = 3
b = 2

s,r,p,d = ejemplo1(a,b) # Desempaquedado
print(s)
# Out:
# Los números ingresados son (3, 2)
# 5
# 10

# %%
s,r,*c = ejemplo1(a,b)
print(c)
# Out:
# Los números ingresados son (3, 2)
# [6, 1.5]

# %%
s,r,p,d = ejemplo1(a,b) #unpacking

print(type(s))
print(s)
print(type(r))
print(r)
print(type(p))
print(p)
print(type(d))
print(d)
# Out:
# Los números ingresados son (3, 2)
# <class 'int'>
# 5
# <class 'int'>
# 1
# <class 'int'>
# 6
# <class 'float'>
# 1.5

# %% [markdown]
# ## **1.8 Alcance (Scope) de las variables**
#
# Analizar el siguiente ejemplo:

# %%
a=3
b=1

def suma(a):
  print(f'Dentro de la función a = {a}, b = {b}')
  return a+b

print(suma(1))

print(f'Fuera de la función a = {a}, b = {b}')
# Out:
# Dentro de la función a = 1, b = 1
# 2
# Fuera de la función a = 3, b = 1

# %% [markdown]
# * Las variables `a` (a = 3) y `b` (b = 1) existen en el cuerpo principal del programa.
#
# * Dentro de la función, la variable `a` es Local (parámetro). Al definir `def suma(a):`, creas una nueva variable `a` que solo existe dentro de la función.
#
# * A diferencia de `a`, la variable `b` no está definida como parámetro ni se crea dentro de la función. Como la función no la encuentra dentro de la función, expande su búsqueda al ámbito global. Allí encuentra `b = 1` y utiliza ese valor.

# %% [markdown]
# ## **Localidad y globalidad de una variable**
#
# Una variable puede ser local o global respecto a una función, i.e., el valor de la variable puede existir de forma interna o externa a la función. Por definición, todo parámetro de una función es local a la misma.

# %%
a = 3
b = 0
c = 10 #c es una variable por fuera de la funcion suma, esto es, c es global

def suma(a, b):
    c = a + b #la variable c es local respecto a la funcion suma
    print("Valor de c dentro de la funcion: ", c)
    return c

suma(a, b)
print("Valor de c por fuera de la funcion: ", c)
# Out:
# Valor de c dentro de la funcion:  3
# Valor de c por fuera de la funcion:  10

# %%
print(c)

# %%
dir(list)

# %% [markdown]
# ## **2. Ejercicios**
#
#
# ### 2.1. Escriba una función que reciba los valores de dos catetos de un triángulo rectángulo y retorne el valor de la hipotenusa del triángulo.

# %% [markdown]
# ### 2.2. Crea una función que reciba dos número enteros al usuario y diga si alguno de ellos es múltiplo del otro. El programa debe devolver un valor booleano.

# %% [markdown]
# ### 2.3. Crea la función “calcularMaxMin”  que reciba una lista con valores numéricos y devuelve un **diccionario** valor máximo y el mínimo.

# %% [markdown]
# ### 2.4. Crear una función que reciba un año y retorne un valor booleano (True o False) si el año es bisiesto o no, respectivamente.
#
# **NOTA:** Un año es bisiesto si cumple con alguna de estas dos condiciones:
# * Es divisible por 4 pero no es divisible por 100.
# * Es divisible por 400.
