# %% [markdown]
# # **8. Programación Orientada a Objetos (POO) / Object Oriented Programming (OOP)**
# Fuentes: <br>
# https://realpython.com/python3-object-oriented-programming/ <br>
# https://ellibrodepython.com/programacion-orientada-a-objetos <br>
# https://medium.com/@LuisMBaezCo/overloading-sobrecargar-operadores-en-python-5d7a75e2bfdf <br>
# https://www.youtube.com/watch?v=HtKqSJX7VoM
#
# 8.1. Objetos (Instancia)
#
# 8.2. Clases (El molde)
#
# 8.3. Sintaxis en Python
#
# 8.4. Atributos y Metodos
#
# 8.5. Sobrecarga de Operadores
#
# 8.6. Herencia

# %% [markdown]
# ## **8.1. Objetos (Instancia)**
#
# En muchos lenguajes de programación, existen distinciones marcadas entre "tipos de datos primitivos" (como números) y "objetos". **En Python, esta barrera no existe, ya que absolutamente todo es un objeto**.
#
# * Cada vez que se define una variable (ya sea un número entero, un flotante o un número complejo, estás creando un objeto (una instancia) de una clase predefinida.
# * Al ser objetos, estos elementos no solo almacenan un valor (estado), sino que también traen consigo **atributos** y **métodos** (comportamiento) que podemos consultar mediante la función `dir()`.

# %%
c = 5 + 4j
c
# Out:
# (5+4j)

# %%
type(c)
# Out:
# complex

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
dir(complex)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  'conjugate',
#  'imag',
#  'real']

# %%
c.imag
# Out:
# 4.0

# %%
c.real
# Out:
# 5.0

# %%
c.conjugate()
# Out:
# (5-4j)

# %% [markdown]
# ## **8.2. Clases (El molde)**
#
# La programación orientada a objetos en Python organiza el código mediante class (clases) para crear modelos de objetos que agrupan atributos (datos) y métodos (comportamientos).
#
# Una clase es una plantilla o un "plano" que define la estructura y el comportamiento de algo. No es el objeto real, sino las instrucciones de cómo construirlo.
#
# Por ejemplo, el número `a = 3` es de clase 'int', mientras que el número `b = 3.0` es de clase 'float'.

# %%
a = 3  ; b= 3.0
print('La clase de a es: ',type(a))
print('La clase de b es: ',type(b))
# Out:
# La clase de a es:  <class 'int'>
# La clase de b es:  <class 'float'>

# %% [markdown]
# * La clase determina cuáles serán los métodos y atributos de un objeto.
# * En este ejemplo, ´a´ y ´b´ NO son clases, son instancias u objetos

# %% [markdown]
# ## **8.3. Sintaxis en Python**
#
# Si bien Python ya trae clases integradas, pero el verdadero potencial de la **POO** reside en la capacidad de crear clases nuevas para modelar problemas específicos.
#
# <br>
#
# Para definir una clase, utilizamos la palabra reservada class seguida del nombre (por convención, usando CamelCase):
#
#
# <font color="#130eb3" size=5>__class__</font> <font size=5>NombreClase(ClasePadre)</font> <font color="#130eb3" size=5>__:__</font>
#
#     Cuerpo

# %% [markdown]
# En su forma más simple, podemos crear una clase "vacía" usando la palabra pass, la cual nos servirá como un *contenedor básico* sin ningun metodo o atributos. Sobre este clase se empieza a construir la lógica de nuestro programa.
#
# En este caso vamos a crear la clase **ProgAvanzada**:

# %%
class ProgAvanzada:
    pass

# %%
print(type(ProgAvanzada))
# Out:
# <class 'type'>

# %% [markdown]
# A continuacion creamos la instancia (objeto) de la clase **ProgAvanzada**, de esta forma se está creando un objeto único en la memoria:

# %%
asignatura = ProgAvanzada()

# %%
print(type(asignatura))
# Out:
# <class '__main__.ProgAvanzada'>

# %% [markdown]
# * **NOTA:**    `__main__` es el nombre del entorno donde se está ejecutando el código actualmente (el notebook).
# * **ProgAvanzada** es la clase y **asignatura** es el objeto.

# %% [markdown]
# Podemos observar los **metodos** con los que se inicia una clase en Python usando `dir()`.

# %%
print(dir(ProgAvanzada))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__']

# %%
print(dir(asignatura))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__']

# %% [markdown]
# * **¿Por qué aparecen estos métodos si no los hemos definido?**
#
# Una clase o una instancia recién creadas no "nacen" vacías. En Python, todas las clases heredan automáticamente de una clase base llamada **object**. Esto significa que:
#
# * Obtienen métodos y atributos por defecto para poder existir y comportarse como un objeto dentro del sistema de Python (Reciben una "caja de herramientas" base).
#
# * Gracias a estos métodos, Python sabe cómo comparar dos objetos, cómo convertirlos a texto o cómo borrarlos de la memoria (Obtienen una funcionalidad básica).

# %% [markdown]
# Podemos crear un objecto en python, y observar que es similar a una clase de Python.

# %%
a2 = object()
print(dir(a2))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %% [markdown]
# ## **8.4. Atributos y Métodos**
# ### **8.4.1 Atributos**
# Todas variables o atributos de la clase, se guardan dentro de la clase por medio del objeto `self` (en español "uno mismo"). Tambien se pueden definir los atributos inmediatamente despues de definir el nombre de la clase y su tipo.

# %%
class Clase1:
  x = 2
  def __init__(self):
    self.y = self.x + 1

# %% [markdown]
# * `x= 2` es un atributo de la Clase1. Es una variable compartida por todos los objetos que se creen de esa clase
# *  `__init__` es el método constructor, que actúa como la puerta de entrada para configurar el objeto.
# Sin él, el objeto no sabría qué valores iniciales tomar al nacer.
# * `self` es una referencia al objeto específico que se está creando, permitiéndole acceder a sus propios datos
# * `self.x` en un atributo de clase. Esta línea busca el valor de `x` (que es 2) para realizar el cálculo inicial del objeto.
# * `self.y` es un atributo de instancia, es una variable única para cada objeto individual.

# %%
class Clase1:
  x = 2
  def __init__(self):
    self.y = self.x + 1

instancia1 = Clase1()
print(instancia1.x, instancia1.y)
# Out:
# 2 3

# %% [markdown]
# * `instancia1` es un objeto (instancia) creada a partir del **molde** Clase1.
# * `instancia1.x` es un **Atributo de Clase**. Pertenece a la clase y todas las instancias lo comparten (inicialmente).
# * `instancia1.y` es un  **Atributo de Instancia**. Pertenece exclusivamente a `instancia1` y se crea en el momento en que el objeto "nace".

# %%
print(type(Clase1))
print(type(instancia1))
# Out:
# <class 'type'>
# <class '__main__.Clase1'>

# %% [markdown]
# * Analicemos el siguiente ejemplo:

# %%
instancia1.x = 4
print(instancia1.x,instancia1.y)
# Out:
# 4 3

# %% [markdown]
# Modificar un atribujo no 'inicia' el método constructor, por tanto, `instancia.y` no cambia.

# %% [markdown]
# <font color="#130eb3" size=3> **NOTA:**
#
# <font color="#130eb3" size=3> La sintaxis es casi idéntica a las usadas para crear funciones, porque un método es (en esencia) una función que vive dentro de una clase.

# %% [markdown]
# ### **8.4.2. Ejemplos**
#
# * **Ejemplo 1:** Veamos cómo modelar un objeto físico, definiendo una **clase** que define qué características tiene un coche (atributos) y qué puede hacer.

# %%
class Auto:
    def __init__(self, marca, referencia, modelo, color,*args):   # aquí el constructor recibe datos externos (marca, referencia, modelo) al momento de nacer.
        # Aquí se definen los atributos de instancia: cada coche tendrá los suyos
        self.marca = marca
        self.referencia = referencia
        self.modelo = modelo
        self.color = color
        self.args = args

# %%
# Creamos una instancia (un auto real)
mi_carro = Auto("Seat", "Arona",2024, 'Gris',23000)

print(f"Marca: {mi_carro.marca}")
print(f"Referencia: {mi_carro.referencia}")
print(f"Modelo: {mi_carro.modelo}")
print(f"Color: {mi_carro.color}")
print(f"Otros: {mi_carro.args}")
# Out:
# Marca: Seat
# Referencia: Arona
# Modelo: 2024
# Color: Gris
# Otros: (23000,)

# %%
tu_carro = Auto("Renault", "duster",2000, 'Blanco')
print(f"Marca: {tu_carro.marca}")
print(f"Referencia: {tu_carro.referencia}")
print(f"Modelo: {tu_carro.modelo}")
print(f"Color: {tu_carro.color}")
print(f"Otros: {tu_carro.args}")
# Out:
# Marca: Renault
# Referencia: duster
# Modelo: 2000
# Color: Blanco
# Otros: ()

# %%
print(mi_carro)

# %% [markdown]
# **NOTA:** Se puede usar el método `__str__` para personalizar como se se ve el objeto cuando alguien intenta convertirlo en texto o imprimirlo.

# %%
class Auto:
    def __init__(self, marca, referencia, modelo, color):
        self.marca = marca
        self.referencia = referencia
        self.modelo = modelo
        self.color = color
    def __str__(self):
        return 'Marca: ' + self.marca + '\nReferencia: ' + self.referencia + '\nModelo: ' + str(self.modelo) + '\nColor: ' + self.color

mi_carro = Auto("Seat", "Arona",2024, 'Gris')
print(mi_carro)
# Out:
# Marca: Seat
# Referencia: Arona
# Modelo: 2024
# Color: Gris

# %%
tu_carro = Auto("Renault", "duster",2000, 'Blanco')

print(tu_carro)
# Out:
# Marca: Renault
# Referencia: duster
# Modelo: 2000
# Color: Blanco

# %% [markdown]
# * **Ejemplo 2:** Crear una clase para manejar Usuarios, debe tener propiedades como: nombre, edad, sexo, fecha de nacimiento (Crear una clase para manejar las fechas). Para crear una instancia de la clase se necesita que la clase reciba mínimo como parámetro de entrada el nombre de la persona.

# %%
class Fecha:
  def __init__(self, day=1, month=1, year=1900):
    self.day = day
    self.month = month
    self.year = year
  def __str__(self):
    return str(self.day)+'-'+str(self.month)+'-'+str(self.year)

ultimaNavidad =  Fecha(25,12,2025)
print(f'La última navidad fue el {ultimaNavidad}')
ProximoSabado = Fecha(14,3,2026)
print(f'El próximo sábado será el {ProximoSabado}')
# Out:
# La última navidad fue el 25-12-2025
# El próximo sábado será el 14-3-2026

# %%
class Usuario:
  def __init__(self, name='Pepito'):
    self.name = name
    self.age = 100
    self.sex = 'no binario'
    self.birthday = Fecha()
  def __str__(self):
    return ' nombre: ' + self.name + '\n Edad: ' + str(self.age) + '\n Sexo: ' + str(self.sex)+\
        '\n Fecha de nacimiento: '+str(self.birthday)

# %%
Juancho = Usuario('Juan Sebastian')

print(Juancho)
# Out:
#  nombre: Juan Sebastian
#  Edad: 100
#  Sexo: no binario
#  Fecha de nacimiento: 1-1-1900

# %%
Juancho = Usuario('Juan Sebastian')
Juancho.age = 21
Juancho.sex = 'H'
Juancho.birthday = Fecha(20,7,2001)

print(Juancho)
# Out:
#  nombre: Juan Sebastian
#  Edad: 21
#  Sexo: H
#  Fecha de nacimiento: 20-7-2001

# %%
print(Juancho.age)    # Atributo de instancia
# Out:
# 21

# %%
Usuario().age         # Atributo de clase
# Out:
# 100

# %%
print(Juancho)
# Out:
#  nombre: Juan Sebastian
#  Edad: 21
#  Sexo: H
#  Fecha de nacimiento: 20-7-2001

# %% [markdown]
# **NOTA:** En este ejemplo creamos la clase `Fecha` para practicar cómo un objeto puede contener a otro. Sin embargo, en el mundo profesional, se recomienda aprovechars las herramientas del lenguaje.

# %% [markdown]
# * **Ejemplo 3:** Argumentos de entrada:
# Funcionan igual a las funciones.

# %%
class Clase:
  y = 2
  def __init__(self, x=0):
    self.z = x + 1

# %%
b = Clase(10)
print(b.y, b.z)
# Out:
# 2 11

# %%
b = Clase(x=10)
print(b.y, b.z)
# Out:
# 2 11

# %% [markdown]
# ### **8.4.3. Ejercicio**
#
# 1. Crea una clase llamada `Dimensiones` que reciba largo, ancho y alto en su constructor (utilizando `0` como valor por defecto), y que imprima el las dimensiones del producto en cm.
# 2. Crea una clase llamada `Producto` que reciba nombre, precio y un objeto de tipo Dimensiones.
# 3. Haz que la clase `Producto` imprima el las dimensiones y el precio del producto.
# 4. Crea un producto llamado `CajaDeHerramientas`, asígnale un precio de 50.000 y unas dimensiones de 30x20x15.
# 5. Crea otros dos productos.
# *******************
# 6. Añade un **método** a `Producto` llamado `volumen()` que devuelva el volumen del producto.
# 7. Haz que la clase `Producto` también imprima el volumen calculado.

# %%
# Resolver el ejercicio en esta celda (si quiere puede agregar más)

# %% [markdown]
# ## **TAREA**
#
# 1. Consultar cómo podría resolverse el ejemplo del método **Usuario** usando el módulo `datetime` (Sin crear la clase `Fecha`).
#
# 2. Crear la clase Usuario usando `*args` o `**kwargs`. Recuerde que se necesita que la clase reciba mínimo como parámetro de entrada el nombre de la persona.

# %%
# Resolver el ejercicio en esta celda (si quiere puede agregar más)

# %% [markdown]
# ***************************************************************************************************

# %% [markdown]
# ***************************************************************************************************

# %% [markdown]
# ***************************************************************************************************

# %% [markdown]
# ### **8.4.4. Metodos**
# Los metodos son las funciones que se definen dentro de la clase. Los metodos pueden emplear atributos o argumentos externos al momento de ser invocados. Por ejemplo creamos una clase llamada `vector2d` que almacena las componentes en los ejes horizontal y vertical. Posteriormente creamos un medodo (una funcional dentro de la clase) que reciba un vector y los sume con la instancia.

# %%
class vector2d:
  def __init__(self, x, y):
    self.x = x
    self.y = y
  def suma(self, vector):
    # Sumar dos Vectores
    return vector2d(self.x + vector.x, self.y + vector.y)

# %%
vector1 = vector2d(3,4)
vector2 = vector2d(4,3)
vector3 = vector1.suma(vector2)
print(f"La suman en el eje x es: {vector3.x}, y en el eje y es: {vector3.y}")
# Out:
# La suman en el eje x es: 7, y en el eje y es: 7

# %% [markdown]
# ## 4. Sobrecarga de operadores
# Podemos definir que operacion realizar de acuerdo a la operacion que se este realizando con una instancia de la clase. Por ejemplo definir que pasa con b + c, si las variables b y c son de una clase nueva. <br>

# %%
class vector2d:
  def __init__(self, x, y):
    self.x = x
    self.y = y
  def __add__ (self, vector):
    # Sumar dos Vectores
    return vector2d(self.x + vector.x, self.y + vector.y)

# %%
a = vector2d(2,3)
b = vector2d(4,5)
c = a+b
print(c.x,', ',c.y)
# Out:
# 6 ,  8

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'x',
#  'y']

# %% [markdown]
# Ejercicio: Averiguar mas metodos que se peuden sobrecargar, como

# %%
#__sub__, __repr__, __str__, __rmul__, __mul__

# %% [markdown]
# ## Ejercicio 1
# - Diseñar una clase para modelar vectores de n-dimensiones, por medio de listas. Debe tener como atributos: los valores y el tamaño del vector. Sobrecargar la clase de tal manera que se puede realizar la suma entre vectores elemento a elemento. Tambien sobrecargar la resta y la multiplicacion.

# %%
class Vector:
  def __init__(self, values):
    self.values = values
    self.size = len(values)

  def __add__ (self, vector): #Sumar dos Vectores
    #Hacer codigo aqui
    pass

# %% [markdown]
# ## Ejercicio 2
# Diseñar una clase para modelar puntos en dos dimensiones [x,y]:
# - Cuando se imprima alguna instancia de la clase, se debe devolver "(x: valor, y: valor)".
# - Sobrecargar el operador de suma para hacer sumas entre instancias de la misma clase. Retornar una instancia de la clase con la suma de los elementos.
# - Sobrecargar la resta, la multiplicacion.
# - Sobrecargar las operaciones >, <, >=, <= (GT, lt, ge, le)

# %% [markdown]
# ## 5. Herencia
# Es un concepto fundamental en la programacion orientada a objetos. La idea es crear clases u objetos a partir de otra clase, y heredar los atributos y metodos de la clase madre/padre. Como ejemplo creamos una clase animal y una subclase Perro:

# %%
# Definimos una clase padre
class Animal:
    pass

# Creamos una clase hija que hereda de la padre
class Perro(Animal):
    pass

# %% [markdown]
# Podemos ver sí la clase `Perro` es subclase de la clase `Animal`:

# %%
print(Perro.__bases__)
# Out:
# (<class '__main__.Animal'>,)

# %% [markdown]
# Y podemos imprimir las subclases asociadas a la clase `Animal`

# %%
print(Animal.__subclasses__())
# Out:
# [<class '__main__.Perro'>]

# %% [markdown]
# ### 5.1 Extensión y modificación de métodos de una clase padre
#
# Creamos la clase general para los animales, con atributos `specie` y `age` para el tipo de especie y la edad del animal. Adicionalmente, los metodos `speak`, `move` y `describe`, como se define a continuación:

# %%
class Animal:
    def __init__(self, specie, age):
        self.specie = specie
        self.age = age

    # Método genérico pero con implementación particular
    def speak(self):
        # Método vacío
        pass

    # Método genérico pero con implementación particular
    def move(self):
        # Método vacío
        pass

    # Método genérico con la misma implementación
    def describe(self):
        print("Soy un Animal del tipo", type(self).__name__)

# %% [markdown]
# Ahora creamos dos clases hijas a partir del padre `Animal` y modificamos los metodos:

# %%
class Perro(Animal):
    def hablar(self):
        print("Guau!")
    def moverse(self):
        print("Caminando con 4 patas")

class Pollo(Animal):
    def hablar(self):
        print("Pio! Pio!")
    def moverse(self):
        print("Caminando con 2 patas")

# %%
chiguagua = Perro('mamimefero',11)
Claudio = Pollo('Oviparo',2)

# %%
print(chiguagua.specie)
# Out:
# mamimefero

# %%
chiguagua.hablar()
Claudio.hablar()
# Out:
# Guau!
# Pio! Pio!

# %% [markdown]
# ### 5.2 Uso de `super()`
#
# El uso de `super()` nos permite acceder a los metodos de la clase padre desde una clase hija.

# %%
class Animal:
    def __init__(self, especie, edad):
        self.especie = especie
        self.edad = edad
    def hablar(self):
        pass

    def moverse(self):
        pass

    def describeme(self):
        print("Soy un Animal del tipo", type(self).__name__)

# %% [markdown]
# Tal vez queramos que nuestro Perro tenga un parámetro extra en el constructor, como podría ser el dueño. Para realizar esto tenemos dos alternativas:
# - Podemos crear un nuevo `init` y guardar todas las variables una a una.
# - O podemos usar super() para llamar al `init` de la clase padre que ya aceptaba la especie y edad, y sólo asignar la variable nueva manualmente.

# %%
class Perro(Animal):
  def __init__(self, especie, edad, dueño=Usuario()):
    # Alternativa 1
    self.especie = especie
    self.edad = edad
    self.dueño = dueño

class Perro2(Animal):
  def __init__(self, especie, edad, dueño):
    # Alternativa 2
    super().__init__(especie, edad)
    self.dueño = dueño

# %%
streeter = Perro('mamifero',5)

# %%
print(streeter.dueño)
# Out:
#  nombre: Pepito
#  Edad: 100
#  Sexo: no binario
#  Fecha de nacimiento: 1-1-1900

# %% [markdown]
# ### 5.3 Herencia multiple

# %% [markdown]
# Tambien se puede realizar herencia a partir de mas de una clase. Por ejemplo,  creamos la clase Padre y Madre, y construimos una clase Hijo que herede los metodos y atributos de Padre y Madre.

# %%
# Definicion clase para Padre
class Padre():
	# Metodo de la clase Padre
	def canta(self):
		print("Papá canta bien.")

# Definicion clase para Madre
class Madre():
	# Metodo de la clase Madre
	def programa(self):
		print("Mamá programa bien.")

# Definicion de la clase derivada
class Hijo(Padre, Madre):
	def jugar(self):
		print("Al niño le encanta jugar")

# creando un objeto de la clase derivada
niño = Hijo()
# llamando a los metodos de las clases padres y la derivada
niño.canta()
niño.programa()
niño.jugar()
# Out:
# Papá canta bien.
# Mamá programa bien.
# Al niño le encanta jugar

# %% [markdown]
# ### 5.4 Multi resolution order

# %% [markdown]
# El problema del diamente: consiste en realizar multiple herencia de clases con padre comun.
# <img src="https://cdn-media-1.freecodecamp.org/images/1*QVZomxLNxnRYhm9gGIfYyw.png">

# %%
class Person:
	def display(self):
		print("Person called")

class Father(Person):
	def display(self):
		print("Father called")

class Mother(Person):
	def display(self):
		print("Mother called")

class Child(Father, Mother):
	pass

child_obj = Child()
child_obj.display()
# Out:
# Father called

# %% [markdown]
# Como hacemos para saber quien tiene mas jerarquia o de cual padre se usan los metodos, si tienen igual nombre, en este caso el metodo `display`.

# %%
Child.__mro__
# Out:
# (__main__.Child, __main__.Father, __main__.Mother, __main__.Person, object)

# %% [markdown]
# Ejercicio Herencia Multiple:
# * Diseñar una clase Persona que reciba los parametros de nombre, edad y nacionalidad, con metodo hablar el cual retorna el texto "Hola mundo!". Definir la clase artista que reciba el parametro habilidad y metodo mostrarHabilidad que retorne el texto "Mi hablidad es {habilidad}". Finalmente diseñar la clase PersonaArtista que reciba nombre, edad, nacionalidad, habilidad, empresa, salario, emplear los constructores de las clases Persona y Artista, y agregar las propiedades de salario y empresa; definir un metodo de presentacion de la PersonaArtista, donde se retorne un texto "Hola soy {nombre}, mi habilidad es {habilidad} y gano {salario}".
# * Analizar para que sirven las funciones `isinstance` y `issublcass`.
