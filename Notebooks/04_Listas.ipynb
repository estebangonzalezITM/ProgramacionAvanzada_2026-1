# %% [markdown]
# # **Clase 4: Listas**
#
# Notebook diseñado por los docentes Andres Castro y Leonardo Duque.
#
# Modificado por Cristian Guarnizo y Esteban Gonzalez Valencia.

# %% [markdown]
# # **1. Estructuras de datos**
#
# Las **listas** y **tuplas** son elementos de python que son contenedores de información.
#
# **Principales Diferencias**
#
# 1. Mutabilidad
#     * Listas (mutable): Puedes cambiar sus elementos, agregar nuevos  o eliminar los existentes. Las listas son dinámicas y su tamaño es dinámico.
#
#     * Tuplas (immutable): No puedes cambiar, añadir ni eliminar elementos una vez definida. Si intentas hacerlo, Python te dará un error. Las listas son fijas y su tamaño es estático
#
# 2. Sintaxis
#     * Listas: Se definen usando corchetes [].
#
#     * Tuplas: Se definen usando paréntesis ().
#
# 3. Rendimiento y Memoria
#     * Listas: Al ser dinámicas, consumen un poco más de memoria y son ligeramente más lentas de procesar.
#
#     * Tuplas: Son más ligeras y rápidas. Python "sabe" que no van a cambiar, por lo que optimiza el espacio que ocupan en la memoria.

# %% [markdown]
# ## **1.1. Listas**
#
# Una lista es un estructura de datos que nos permite almacenar secuencias de elementos. Una lista tiene las siguientes propiedades:
#
# - Permite almacenar cualquier tipo de elemento.
# - Es dinámica, esto es, puede cambiar su tamaño dinámicamente.
#
# La sintaxis en Python es la siguiente:
#
# $lista$ = <font color="blue" size=5>[</font> $elemento_1$, $elemento_2$, $elemento_3$,...,$elemento_n$ <font color="blue" size=5>]</font>

# %% [markdown]
# Las lista se puede crear usando alguno de los comandos:
#
# *   `[]`    ............Se usa para crear una lista nueva desde cero.
# *   `list()` ...Se usa para convertir otro tipo de dato (como un rango o tupla) en lista.

# %%
# 20 , 'string' , 3.5 , 85+4j , [30,60,10]
#  range(5,50,5)

lista1 = [  ]
lista2 = list(  )
print("lista1: ",lista1)
print("lista2: ",lista2)
# Out:
# lista1:  [20, 'string', 3.5, (85+4j), [30, 60, 10]]
# lista2:  [5, 10, 15, 20, 25, 30, 35, 40, 45]

# %% [markdown]
# Tambien podemos agregar valores a la lista para inicializarla.

# %% [markdown]
# ![](https://pynative.com/wp-content/uploads/2021/03/python-list.jpg)

# %%
#Crear lista con diferentes valores (tipos)
lista = [ 20 , 'string' , 3.5 , 85+4j , [30,60,10] ]       #enteros, texto,  floantes, complejos, lista      # 20 , 'string' , 3.5 , 85+4j , [30,60,10]
#imprimir lista
print(lista)

#tipo de variable?
type(lista)

#len (length) para tamaño
len(lista)
# Out:
# [20, 'string', 3.5, (85+4j), [30, 60, 10]]
# 5

# %% [markdown]
# Podemos acceder a los elementos de las lista usando valores enteros, empezando con 0 y terminando con el tamaño de la lista menos 1. Tambien podemos acceder a los elementos usando indexacion negativa.
# ![](https://pynative.com/wp-content/uploads/2021/02/positive-and-negative-indexing.jpg)

# %%
lista = [ 20 , 'string' , 3.5 , 85+4j , [30, 60, 10] ]
#          0       1       2       3            4       --> Positive indexing
#         -4      -3      -3      -2           -1       --> Negative indexing

#imprimir un elemento de la lista
lista[0]

#Indexación lista[-1]: indexación negativa
# Out:
# 20

# %% [markdown]
# Se conoce como  **Slicing** a la técnica que se usas en Python para extraer una subsección de una secuencia, como una lista, una tupla o una cadena de texto.

# %%
lista = [ 20 , 'string' , 3.5 , (85+4j) , [30, 60, 10] , 50 , 'texto' ]
#          0       1       2       3            4         5      6
print(lista ,'\n')

#Sublistas (slicing)
lista[:2]

# inicio : fin : pasos
# Out:
# [20, 'string', 3.5, (85+4j), [30, 60, 10], 50, 'texto']
# [20, 'string']

# %%
#  Modificación de elementos de la lista
lista = [ 20 , 'string' , 3.5 , 85+4j , [30, 60, 10] , 50 , 'texto' ]

lista[] = []     # Listas son mutables
print(lista)
# Out:
# [20, 'string', 3.5, [10, 5, 6], [30, 60, 10], 50, 'texto']

# %%
print(lista ,'\n')
#Podemos asignar sublistas a nuevas variables
subL = lista[:3]
print(subL)
print(type(subL),'\n')

lista[3] = subL
print(lista)
# Out:
# [20, 'string', 3.5, [20, 'string', 3.5], [30, 60, 10], 50, 'texto']
#
# [20, 'string', 3.5]
# <class 'list'>
#
# [20, 'string', 3.5, [20, 'string', 3.5], [30, 60, 10], 50, 'texto']

# %% [markdown]
# ## **slicing** con str

# %%
#crear str
cadena = 'Programacion Avanzada'
print(cadena)

#Hacer slicing

cadena[3] = 'o'    # Los strings (cadenas de texto) son inmutables
# Out:
# Programacion Avanzada
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3813708684.py in <cell line: 0>()
#       5 #Hacer slicing
#       6
# ----> 7 cadena[3] = 'o'    # Los strings (cadenas de texto) son inmutables
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## **Operaciones básicas sobre listas**
#
# A continuación algunas operaciones sobre las listas. Para mayor información, consultar: https://docs.python.org/3/tutorial/datastructures.html
#
#
# <p float="left">
#   <img src="https://i.pinimg.com/736x/65/d3/33/65d33376a75509a09641ff987fff5770.jpg" width="400" />
#   <img src="https://i.pinimg.com/736x/52/4c/4b/524c4b946f419bcc136c3737c5f84ca4.jpg" width="400" />
# </p>

# %% [markdown]
# **Métodos de las listas**

# %%
# Metodos de las listas
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
mi_lista = [ 1 , 2 , 3 , 2.5 , "Juan" ] #crear lista con elementos
print(mi_lista, '\n')

#método append
mi_lista.append(5.0)
print(mi_lista)
# Out:
# [1, 2, 3, 2.5, 'Juan']
#
# [1, 2, 3, 2.5, 'Juan', 5.0]

# %%
#método insert
mi_lista.insert(3,'Andres')
print(mi_lista)
# Out:
# [1, 2, 3, 'Andres', 2.5, 'Juan', 5.0]

# %% [markdown]
# # Método pop

# %%
print(mi_lista)
elementoRemovido = mi_lista.pop()
print(elementoRemovido)
print(mi_lista)
# Out:
# [1, 2, 3, 'Andres', 2.5, 'Juan', 5.0]
# 5.0
# [1, 2, 3, 'Andres', 2.5, 'Juan']

# %%
# elementoRemovido = mi_lista.pop(3)
print(elementoRemovido)
print(mi_lista)
# Out:
# 5.0
# [1, 2, 3, 'Andres', 2.5, 'Juan']

# %%
del mi_lista[1:4]
print(mi_lista)
# Out:
# [1, 2.5, 'Juan']

# %% [markdown]
# # Las listas se pueden sumar (concadenar)

# %%
lista2 = [1,1,1,1,3,4,5]
mi_lista = lista2 + mi_lista   # concatenacion de lista
print(mi_lista)
# Out:
# [1, 1, 1, 1, 3, 4, 5, 1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan', [3, 10, 210], 3, 10, 210, [3, 10, 210], [3, 10, 210], 3, 10, 210]

# %%
mi_lista = mi_lista +[3,10,210]
print(mi_lista)
# Out:
# [1, 1, 1, 1, 3, 4, 5, 1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan', [3, 10, 210], 3, 10, 210, [3, 10, 210], [3, 10, 210], 3, 10, 210, 3, 10, 210]

# %% [markdown]
# # **Algunos métodos de las listas**

# %% [markdown]
# # Métodos *count* y *replace*

# %%
cadena = 'Programacion Avanzada'
print(cadena)
cadena.count('a') #Cuenta cuantos elementos de la cadena de caracteres son 'a'
# Out:
# Programacion Avanzada
# 5

# %%
print(cadena,'\n')
print(cadena.replace('a','A'))     # .replace es un metodo del tipo de datos String

# cadena = cadena.replace('a','A')   # Reescribe el objeto 'cadena'
# print(cadena)
# Out:
# Programacion Avanzada
#
# ProgrAmAcion AvAnzAdA

# %%
mi_lista = [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan']

print(mi_lista)

# método .count
print(mi_lista.count(1))
# Out:
# [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan']
# 5

# %% [markdown]
# # Palabra reservada <font color="#130eb3">__in__</font>

# %%
#
print(1 in mi_lista)
# Out:
# True

# %%
#método extend
mi_lista.extend([7,8,9])
print(mi_lista)
# Out:
# [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan', 7, 8, 9]

# %%
mi_lista.extend('LPW') # +
print(mi_lista)
# Out:
# [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan', 7, 8, 9, 'L', 'P', 'W']

# %% [markdown]
# # Diferencia entre *append* y *extend*

# %%
mi_lista = [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan']
print(mi_lista,'\n length:',len(mi_lista),'\n')

mi_lista.append([3,10,20])
print(mi_lista,'\n length:',len(mi_lista),'\n')
# Out:
# [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan']
#  length: 10
#
# [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan', [3, 10, 20]]
#  length: 11

# %%
mi_lista.extend([3,10,20])
print(mi_lista,'\n length:',len(mi_lista))
# Out:
# [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan', [3, 10, 20], 3, 10, 20]
#  length: 14

# %% [markdown]
# # Método *remove*

# %%
mi_lista = [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan']

# %%
mi_lista.remove(1)
print(mi_lista)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3692109068.py in <cell line: 0>()
# ----> 1 mi_lista.remove(1)
#       2 print(mi_lista)
#
# ValueError: list.remove(x): x not in list

# %%
mi_lista = [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan']
print(mi_lista,'\n')

# remover todos los valores igual a 1
while(1 in mi_lista):
    mi_lista.remove(1)
    print(mi_lista)
# Out:
# [1, 1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan']
#
# [1, 1, 1, 3, 4, 5, 1, 2.5, 'Juan']
# [1, 1, 3, 4, 5, 1, 2.5, 'Juan']
# [1, 3, 4, 5, 1, 2.5, 'Juan']
# [3, 4, 5, 1, 2.5, 'Juan']
# [3, 4, 5, 2.5, 'Juan']

# %% [markdown]
# # Método reverse

# %%
print(mi_lista)
# #método reverse
mi_lista.reverse()
print(mi_lista)
# Out:
# [3, 4, 5, 2.5, 'Juan']
# ['Juan', 2.5, 5, 4, 3]

# %% [markdown]
# # Método *sort*

# %%
#Organizar los elementos de una lista
list.sort?

# %%
lista2 = [ 1,50,2,3.5,96,-5,32,0]
lista2.sort()
print(lista2)
# Out:
# [-5, 0, 1, 2, 3.5, 32, 50, 96]

# %%
lista3 = ['andres', 'abuelo','a','c','fe','b']
lista3.sort()
print(lista3)
# Out:
# ['a', 'abuelo', 'andres', 'b', 'c', 'fe']

# %%
#parámetros de sort
lista3.sort(reverse=True)
print(lista3)
# Out:
# ['fe', 'c', 'b', 'andres', 'abuelo', 'a']

# %% [markdown]
# # Borrar variables y listas

# %%
#Borrar la variable
# del mi_lista
# print(mi_lista)
del lista3[2]
print(lista3)
# Out:
# ['fe', 'c', 'a']

# %%
#Borrar todos los elementos de la lista (vaciar)
print(mi_lista,'\n')
mi_lista.clear()
print(mi_lista)
# Out:
# [3, 4, 5, 2.5, 'Juan']
#
# []

# %%
del mi_lista
print(mi_lista)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1064647177.py in <cell line: 0>()
#       1 del mi_lista
# ----> 2 print(mi_lista)
#
# NameError: name 'mi_lista' is not defined

# %% [markdown]
# # Método *index*

# %%
# L.index?
L = [1,2,3,4,5,6,7,8,3,3,3]
print(L.index(3))
print(L.index(3,5))
# Out:
# 2
# 8

# %% [markdown]
# # Copiar listas (incorrectamente)

# %%
L1 = [1,3,5]
L2 = L1

print("Lista 1 = ", L1)
print("Lista 2 = ", L2)

print("Lista 1 = ", L1, "...dirección de memoria de L1:",id(L1))
print("Lista 2 = ", L2, "...dirección de memoria de L2:",id(L2))
# Out:
# Lista 1 =  [1, 3, 5]
# Lista 2 =  [1, 3, 5]
# Lista 1 =  [1, 3, 5] ...dirección de memoria de L1: 133691845920256
# Lista 2 =  [1, 3, 5] ...dirección de memoria de L2: 133691845920256

# %%
L2[1] = -50

print("Nueva Lista 1 = ", L1)
print("Nueva Lista 2 = ", L2)
# Out:
# Nueva Lista 1 =  [1, -50, 5]
# Nueva Lista 2 =  [1, -50, 5]

# %% [markdown]
# # Copiar listas con el método *copy* (correctamente)

# %%
#Copiar listas correctamente
L1 = [1,3,5]
L2 = L1.copy()

print("Lista 1 = ", L1, "dirección de memoria de L1:",id(L1))
print("Lista 2 = ", L2, "dirección de memoria de L2:",id(L2))

L2[1] = -50

print("Nueva Lista 1 = ", L1)
print("Nueva Lista 2 = ", L2)
# Out:
# Lista 1 =  [1, 3, 5] dirección de memoria de L1: 133691848279744
# Lista 2 =  [1, 3, 5] dirección de memoria de L2: 133691845744640
# Nueva Lista 1 =  [1, 3, 5]
# Nueva Lista 2 =  [1, -50, 5]

# %% [markdown]
# ## Recorriendo una lista con estructuras repetitivas
#
# Para ello podemos:
#
# 1. Utilizar un rango igual al tamaño de la lista e iterar por cada posición de la lista.
# 2. Iterar por cada elemento de la lista como objeto iterable.

# %%
lista = [ 1.3 , 2.2 , 7 , 4.1 , 4.5E-005 , "hola" , "mundo" , ["a", "b", "c"] ]
print(lista)

print("Longitud de la lista: ",len(lista),'\n')

for i in range(len(lista)): #por índice
    print("Posición",i,': ', lista[i])
# Out:
# [1.3, 2.2, 7, 4.1, 4.5e-05, 'hola', 'mundo', ['a', 'b', 'c']]
# Longitud de la lista:  8
#
# Posición 0 :  1.3
# Posición 1 :  2.2
# Posición 2 :  7
# Posición 3 :  4.1
# Posición 4 :  4.5e-05
# Posición 5 :  hola
# Posición 6 :  mundo
# Posición 7 :  ['a', 'b', 'c']

# %% [markdown]
# ### Otra forma:

# %%
lista = [ 1.3 , 2.2 , 7 , 4.1 , 4.5E-005 , "hola" , "mundo" , ["a", "b", "c"] ]
print(lista,'\n')
cont = 0
for elemento in lista: #elemento a elemento
#     print(elemento)
    print(f"posición {cont}: {elemento}")
    cont += 1
# Out:
# [1.3, 2.2, 7, 4.1, 4.5e-05, 'hola', 'mundo', ['a', 'b', 'c']]
#
# posición 0: 1.3
# posición 1: 2.2
# posición 2: 7
# posición 3: 4.1
# posición 4: 4.5e-05
# posición 5: hola
# posición 6: mundo
# posición 7: ['a', 'b', 'c']

# %% [markdown]
# El comando range(len(lista)) te permite obtener los índices, enumerate() es la versión "pro" y elegante de Python para hacer exactamente lo mismo, pero de forma mucho más limpia.
#
# > Añadir blockquote

# %%
for i, elemento in enumerate('Hola Mundo!'): #con enumerate para tener tanto índice, como elemento
    print(f"posición {i}: {elemento}")
# Out:
# posición 0: H
# posición 1: o
# posición 2: l
# posición 3: a
# posición 4:
# posición 5: M
# posición 6: u
# posición 7: n
# posición 8: d
# posición 9: o
# posición 10: !

# %%
enumerate('Hola Mundo!')

# %%
print(lista)
for i, elemento in enumerate(lista):
    print(f"El elemento de la posición {i} es {elemento}")

# %%
#Solicitar a un usario 10 valores y almacenarlos en una lista

lista = []

while len(lista) < 10:
    num = input("Ingrese un número: ")
    if num == 'q':
        break
    lista.append(float(num))

print(lista)

# %% [markdown]
# ## Comprensión de listas (List Comprehension)
#
# Esto es una manera concisa de crear listas, ahorrándonos el proceso ingresar la asignación de valores de la lista dentro de un ciclo.

# %%
#Parecido al inline if -->  True if x%2==0 else False

X = range(0, 11)

lista = []
print(lista)

for x in X:
    lista.append(x**2)

print(lista)

# %% [markdown]
# En el ejemplo anterior hemos creado una lista de los cuadrados de los elementos en una lista de la siguiente forma:
#
# <center><font size=5>$lista=x^2 \qquad \forall x \in X=[0,10]$</font></center>
#
# Podemos leer la expresión anterior como:
#
# <br>
# <center><font size=3><i>"lista es igual a x al cuadrado, para todo x que pertenece a X en el rango 0 a 10."</i></font></center>
#
# Podemos utilizar la expresión anterior para pensar un poco en la compresion de lista. Observemos el
# siguiente ejemplo:

# %%
X = range(0, 11)

lista2 = [x**2 for x in X] #lista es igual a x al cuadrado, para todo x que pertenece a X en el rango 0 a 10.

print(lista2)

# %% [markdown]
# ## Otro ejemplo

# %%
Ejemplo2 = []

for i in range(1,5):
    Ejemplo2.append(2*i-1)

print(Ejemplo2)

# %%
L = [(2*i-1) for i in range(1,5)]
print(L)

print(sum(L))

# %%
L = [(2*i-1) for i in range(1,5) if i%2==0]
print(L)

# %% [markdown]
# Como una lista puede almacenar cualquier tipo de elemento, puede almacenar una lista también:

# %%
lista_anidada = [[1,2,3],[4,5,6,7],["Juan", "Pedro", "Pablo"]]

print(lista_anidada)

"""
#El codigo anterior es equivalente a
lista1 = [1,2,3]
lista2 = [4,5,6,7]
lista3 = ["Juan", "Pedro", "Pablo"]

lista_anidada = [lista, lista2, lista3]
"""

print(len(lista_anidada))
print(lista_anidada[1])
print(lista_anidada[2][1])

# %% [markdown]
# ### Ejercicio 1. Almacenemos la tabla de conversión de grados Celsius a Fahrenheit en una lista anidada de la forma: $[[C_0, F_0],[C_1, F_1],...,[C_n, F_n]]$
#
# Recordemos: Generemos una tabla de conversión de grados Celsius a Farenheit en el rango $[-20, 40]$ con __paso=5__

# %%
#Celda para hacer ejercicio

# %% [markdown]
# ### Ejercicio 2. A partir de la siguiente lista, crear un programa que separe en otras dos listas los números pares y los números impares

# %%
lista = [1, 2, 3, 4, 5, 6, 7, 10, 11, 21, 33, 32, 2, 4]

# %%
lista = [1, 2, 3, 4, 5, 6, 7, 10, 'hola', 11, 21, 32.2322, 32, 2, 4,'a', True, [1,2,3]]

# %% [markdown]
# ### Ejercicio 3. Estime la suma de todos los elementos de una lista

# %%
lista = [1,4,6,2,5.8,6.4,99,10,23,67,-45]

# %% [markdown]
# ### Ejercicio 4. Cuente la cantidad de números pares en una lista

# %%
lista = [1,4,6,2,5.8,6.4,99,10,-975.43,23,67,-45]
# Out:
# organizamos la lista
# [-975.43, -45, 1, 2, 4, 5.8, 6, 6.4, 10, 23, 67, 99]
# 4

# %% [markdown]
# ### Ejercicio 5. Calcule y almacene en una lista la suma acumulada de todos los elementos de una lista

# %%
lista = [1, 2, 3, 4, 5, 6, 7, 10, 11, 21, 33, 32, 2, 4]

# %% [markdown]
# ### Ejercicio 6. Escribir un programa que solicite ingresar números hasta que se introduzca un cero. Los números ingresados se deben almacenar en una lista. Finalmente, se debe imprimir la suma y el promedio de todos los números ingresados.
