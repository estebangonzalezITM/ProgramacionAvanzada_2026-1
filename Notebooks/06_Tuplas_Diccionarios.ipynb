# %% [markdown]
# # **1. Tuplas**
#
# ## **1.1 Definición**
#
# Las tuplas son una estructura de datos integrada en Python que permite almacenar una colección de elementos de forma ordenada. Se parecen mucho a las listas, pero tienen una diferencia fundamental que las define: **son inmutables**.
#
# Para crear una tupla, los elementos se encierran entre <font color="blue" size=3>paréntesis () <font color="black" size=3>y se separan por comas. Aunque en muchos casos los paréntesis son opcionales, se recomienda usarlos por claridad.

# %% [markdown]
# * Verificar tipo

# %%
tupla1 = (10, 20, 5, 30)
print((type(tupla1)))

lista = [10, 20, 5, 30]
print((type(lista)))
# Out:
# <class 'tuple'>
# <class 'list'>

# %% [markdown]
# * Ver un elemento de una tupla

# %%
tupla3 = (1, "Hola", 3.14, True)
print(tupla3[3])
# Out:
# True

# %% [markdown]
# * Las entradas de una tupla pueden ser mixtas

# %%
tupla4 = ( 20 , 'string' , 3.5 , 85+4j , [30,60,10],  (50,10) , 'texto',20 )
tupla4
# Out:
# (20, 'string', 3.5, (85+4j), [30, 60, 10], (50, 10), 'texto', 20)

# %% [markdown]
# ## **1.2 Funciones escenciales con tuplas**
#
# `len(tupla)`: Devuelve el tamaño o cantidad de elementos. Fundamental para ciclos for.
#
# `max(tupla)` y `min(tupla)`: Devuelven el valor más alto y más bajo (siempre que los datos sean comparables, como números).
#
# `sum(tupla)`: Suma todos los elementos numéricos.
#
# `sorted(tupla)`: ¡CUIDADO!: Esta función ordena los elementos de la tupla, pero como la tupla es inmutable, devuelve una lista nueva con los elementos ordenados.

# %%
tupla1 = (10, 20, 5, 30)
tupla2 = ("rojo", "verde", "azul")
tupla4 = ( 20 , 'string' , 3.5 , 85+4j , [30,60,10],  50 , 'texto',20 )

# %%
print(sorted(tupla1))
type(sorted(tupla1))
# Out:
# [5, 10, 20, 30]
# list

# %% [markdown]
# ## **1.3 Métodos con tuplas**
#
# Las tuplas tienen solo tienen dos métodos propios. Esto se debe a su naturaleza inmutable: como no se pueden cambiar, agregar o eliminar elementos una vez creadas, no necesitan métodos de modificación.
#
# **Método `.count(valor)`**
#
# Este método cuenta cuántas veces aparece un elemento específico dentro de la tupla. Es útil para validaciones estadísticas o de frecuencia.

# %%
mi_tupla = (1, 2, 3, 1, 1, 4)
print(mi_tupla.count(1))
# Out:
# 3

# %% [markdown]
# **Método `.index(valor)`**
#
# Busca un elemento en la tupla y devuelve el índice (la posición) de su primera aparición. Si el elemento no se encuentra, Python lanza un error (*ValueError*).

# %%
colores = ("rojo", "verde", "azul", "verde")
print(colores.index("verde"))
# Out:
# 1

# %%
# colores.reverse()
# colores.append('amarillo')
# colores.pop()
# print(colores)
# Out:
# ('rojo', 'verde', 'azul', 'verde')

# %% [markdown]
# * Recorrer una tupla

# %%
tupla3 = ( 1.3 , 2.2 , 7 , 4.1 , 4.5E-005 , "hola" , "mundo" , ["a", "b", "c"] )

print("Longitud de la tupla: ",len(tupla3),'\n')

for i in range(len(tupla3)):
    print("Posición",i,': ', tupla3[i])
# Out:
# Longitud de la tupla:  8
#
# Posición 0 :  1.3
# Posición 1 :  2.2
# Posición 2 :  7
# Posición 3 :  4.1
# Posición 4 :  4.5e-05
# Posición 5 :  hola
# Posición 6 :  mundo
# Posición 7 :  ['a', 'b', 'c']

# %% [markdown]
# *********
#
#  **-----------------------------------------------------------------------**
#
# *********

# %% [markdown]
# # **2. Diccionarios**
#
# ## **2.1 Definición**
#
# En Python, los diccionarios son una estructura de datos que permite almacenar información en pares <font color="blue" size=3> llave → valor.
#
# Son útiles cuando quieres acceder a un dato usando un identificador en lugar de una posición numérica (como ocurre en las listas), con la siguiente sintaxis:
#
# $diccionario$ = <font color="blue" size=5>{</font> $key_1:elemento_1$, $key_2:elemento_2$, $key_3:elemento_3$,...,$key_n:elemento_n$ <font color="blue" size=5>}</font>
#
# Donde $key_i$ se refiere a un indicador, llave o clave única para el elemento $i$.

# %%
lista = [1,2,3,4]
tupla = (1,2,3,4)
diccionario = {'llave1':1,'llave2':2,'llave3':3,'llave4':4}

# %% [markdown]
# * Observemos el siguiente ejemplo:

# %%
persona = { "nombre": "Esteban" , "edad": 35 , "profesion": "Docente" }
print(persona)
print(type(persona))
# Out:
# {'nombre': 'Esteban', 'edad': 35, 'profesion': 'Docente'}
# <class 'dict'>

# %% [markdown]
# <font color="red">"nombre" <font color="black">es la llave, <font color="red">"Esteban" <font color="black">es el valor
#
# <font color="red">"edad" <font color="black">es la llave, <font color="red">"35" <font color="black">es el valor
#
# <font color="red">"profesion" <font color="black">es la llave, <font color="red">"Docente" <font color="black">es el valor

# %% [markdown]
# *   Para acceder a un valor se usa la llave (key):

# %%
print(persona["nombre"])
# Out:
# Esteban

# %% [markdown]
# Un diccionario en Python es como un diccionario real, cuando buscas una clave (palabra), obtienes su valor (definición)

# %%
# Una lista equivalente sería
# ¡Cuidado! A diferencia de los diccionarios, para llamar cada elemento debes conocer su posición en la lista
persona_list = ["Esteban",35,"Docente"]
print(persona_list[2])
# Out:
# Docente

# %% [markdown]
# * Es posible crear un diccionario vacío:

# %%
mi_diccionario = {}
print(mi_diccionario)
print(type(mi_diccionario))
# Out:
# {}
# <class 'dict'>

# %% [markdown]
# * Los diccionarios también pueden crearse con el constructor `dict` (aunque la sintaxis puede ser un poco más compleja)

# %%
mi_diccionario = dict()
print(mi_diccionario)
print(type(mi_diccionario))

# %%
# Es equivalente a hacer:
# persona = { "nombre": "Esteban" , "edad": 35 , "profesion": "Docente" }

persona = dict( [("nombre", "Esteban") , ("edad", 30) , ("profesion", "Docente")])
persona

# %% [markdown]
# <font color="red"> ¡¡¡ CUIDADO !!!
#
# Si se usan llaves pero sin pares **llave → valor**, Python crea un set:

# %%
num_set = {1, 2, 3, 4, 1, 2 ,5}
print('Este es un set: ',num_set)
print(type(num_set))
# Out:
# Este es un set:  {1, 2, 3, 4, 5}
# <class 'set'>

# %%
num_dict = {1:0, 2:0, 3:0, 4:0, 1:0, 2:0}
print('Este es un diccionario: ',num_dict)
print(type(num_dict))
# Out:
# Este es un diccionario:  {1: 0, 2: 0, 3: 0, 4: 0}
# <class 'dict'>

# %% [markdown]
# Un *set* **NO es un diccionario**, es un conjunto (no permite elementos repetidos).

# %% [markdown]
# * Las llaves pueden ser de tipo *string, int, float, complex, tuple*
# * Las llaves **NO** pueden de tipo *list, dict, set* (mutables)

# %%
num_dic = { 'uno':1 , 2:'dos' , 3.0:'tres' , 4+4j:'cuatro' , (5,5):5 }
print('Este es un diccionario: ',num_dic)

print(num_dic[4+4j])
# Out:
# Este es un diccionario:  {'uno': 1, 2: 'dos', 3.0: 'tres', (4+4j): 'cuatro', (5, 5): 5}
# cuatro

# %% [markdown]
# * Los atributos y métodos pueden consultarse con el comando:

# %%
dir(dict)

# %% [markdown]
# ## **2.2 Operaciones comunes**
#
# * Agregar elementos:

# %%
persona = { "nombre": "Esteban" , "edad": 35 , "profesion": "Docente" }
print(persona)

persona["ciudad"] = "Medellín"
print(persona)
# Out:
# {'nombre': 'Esteban', 'edad': 35, 'profesion': 'Docente'}
# {'nombre': 'Esteban', 'edad': 35, 'profesion': 'Docente', 'ciudad': 'Medellín'}

# %% [markdown]
# * Modificar elementos:

# %%
persona["edad"] = 39
print(persona)
# Out:
# {'nombre': 'Esteban', 'edad': 39, 'profesion': 'Docente', 'ciudad': 'Medellín'}

# %% [markdown]
# * Eliminar elementos:

# %%
del persona["profesion"]
print(persona)
# Out:
# {'nombre': 'Esteban', 'edad': 39, 'ciudad': 'Medellín'}

# %% [markdown]
# * Recorrer un diccionario:

# %%
for k,v in persona.items():
    #print(f'La llave es {k} y su valor es {v}')
    print(k,v)
# Out:
# nombre Esteban
# edad 39
# ciudad Medellín

# %%
for dato in persona.values():
    print(dato)
# Out:
# Esteban
# 39
# Medellín

# %% [markdown]
# ## **2.3 Métodos de los diccionarios**
#
# * Asumir que tenemos un diccionario definido como  **dic = {'x': 10, 'y':20}**.
#
# | Metodo  | Descripcion  | Salida |
# |---|---|---|
# | .keys()  | Retorna las llaves de un diccionario.  | dict_keys(['x', 'y'])|
# | .values()  | Retorna los valores asociadas a cada llave del diccionario.  | dict_values([10, 20])|
# | .items()  | Retorna en tuplas (llave$_i$,value$_i$)  | dict_items([('x', 10), ('y', 20)]) |
# | .get('x')  | Retorna el valor asociado a la llave.   | 10 |
# | .get('z')  | Si la llave no existe devuelve un *None* por defecto  | None |
# | .get('w',0)  | O devuelve el segundo argumento su la llave no existe.  | 0 |
# | .pop('x')  | Retorna el valor asociado a la llave, <br> y la llave sale del diccionario.  | 10; dic = {'y':20} |
# | .popitem()  | Retorna la ultima llave con su valor en una tupla, <br> y la ultima llave sale del diccionario.  | 20; dic = {'x':10} |
# | .update({'x':15}) | Busca la llave y modifica el valor en el diccionario.  | None; dic = {'x':15, 'y':20} |
# | .update({'z':30}) | Si la llave no existe, agrega la llave y el valor al diccionario.  | None; dic = {'x':10,'y':20,'z':30} |
# | .setdefault('y',50) | Retorna el valor de la llave si la llave esta en el diccionario, <br> de lo contrario devuelve el valor por defecto.  | 20; dic = {'x':10,'y':20} |
# | .setdefault('z',50) | Retorna el valor de la llave si la llave esta en el diccionario, <br> de lo contrario devuelve el valor por defecto.  | 50; dic = {'x':10,'y':20,'z':50} |
# | .clear() | Limpiar el diccionario.  | {} |
# | .copy() | Retornar una copia del diccionario.  | {'x':10, 'y':20} |

# %%
dic = {'x':10, 'y':20}
print(' Diccionario_inicial: ',dic)

metodo = dic.copy()

print('\n Metodo: ',metodo)                  #print(type(metodo))
print('\n Diccionario_salida: ',dic)
#   dic.get('x') -> dic['x']
# Out:
#  Diccionario_inicial:  {'x': 10, 'y': 20}
#
#  Metodo:  {'x': 10, 'y': 20}
#
#  Diccionario_salida:  {'x': 10, 'y': 20}

# %% [markdown]
# * Dependiendo del método, la salida puede convertirse en una lista, usando `list()`

# %%
dic = {'x': 10, 'y':20}

print(' Metodo: ', dic.values() )

valores_lista = list( dic.values() )
print('\n Lista: ',valores_lista)
# Out:
#  Metodo:  dict_values([10, 20])
#
#  Lista:  [10, 20]

# %% [markdown]
# * Ver la ayuda de cada metodo

# %%
help({}.popitem)
# Out:
# Help on built-in function popitem:
#
# popitem() method of builtins.dict instance
#     Remove and return a (key, value) pair as a 2-tuple.
#
#     Pairs are returned in LIFO (last-in, first-out) order.
#     Raises KeyError if the dict is empty.

# %%
#Probar el funcionamiento de cada metodo
dic = {'x': 10, 'y':20}
llavex = dic.setdefault('y',50)
print(llavex)
print(dic)

# %% [markdown]
# * El metodo `fromkeys()` permite crear un diccionario a partir de un objeto iterable de llaves y un valor inicial. Usando este método, todas las llaves comparten el mismo valor

# %%
help({}.fromkeys)
# Out:
# Help on built-in function fromkeys:
#
# fromkeys(iterable, value=None, /) class method of builtins.dict
#     Create a new dictionary with keys from iterable and values set to value.

# %%
dic2 = {}.fromkeys(['x','y','z'],10)
print(dic2)
# Out:
# {'x': 10, 'y': 10, 'z': 10}

# %%
dic2 = {}.fromkeys('xyz',10)
print(dic2)
# Out:
# {'x': 10, 'y': 10, 'z': 10}

# %%
dic3 = dict.fromkeys('xyz',0)
print(dic3)
# Out:
# {'x': 0, 'y': 0, 'z': 0}

# %% [markdown]
# * ¿Como saber si una llave existe?

# %%
Dic = {"primero":1,"segundo": 2, "letra": 'a', 5.1 : [50,5,2,1,6]}

a = 5.1
if a in Dic.keys():
    print(f"La llave {a} SI existe!")
else:
    print(f"La llave {a} NO existe!")
# Out:
# La llave 5.1 SI existe!

# %%
Dic = {"primero":1,"segundo": 2, "letra": 'a', 5.1 : [50,5,2,1,6]}

a = 'a'
if a in Dic.values():
    print(f"El valor {a} SI existe!")
else:
    print(f"El valor {a} NO existe!")
# Out:
# El valor a SI existe!

# %% [markdown]
# * Creando llaves nuevas en diccionarios `dic['llave nueva']` = `valor_nuevo`

# %%
Dic = {"primero":1,"segundo": 2, "letra": 'a', 5.1 : [50,5,2,1,6]}
Dic['llave nueva'] = [1,2,3,4,5]
print(Dic)
# Out:
# {'primero': 1, 'segundo': 2, 'letra': 'a', 5.1: [50, 5, 2, 1, 6], 'llave nueva': [1, 2, 3, 4, 5]}

# %%
Dic[10] = [1,2,3,4,5]
print(Dic)
# Out:
# {'primero': 1, 'segundo': 2, 'letra': 'a', 5.1: [50, 5, 2, 1, 6], 'llave nueva': [1, 2, 3, 4, 5], 10: [1, 2, 3, 4, 5]}

# %% [markdown]
# * Tambien podemos sobre escribir un valor de una llave ya existente

# %%
Dic[10] = [10,20,30]
print(Dic)
# Out:
# {'primero': 1, 'segundo': 2, 'letra': 'a', 5.1: [50, 5, 2, 1, 6], 'llave nueva': [1, 2, 3, 4, 5], 10: [10, 20, 30]}

# %% [markdown]
# ## Ejercicio
# De lo estudiado anteriormente, explicar que realiza el siguiente codigo

# %%
estudiantes = {"Juan":[22, "Casas", "ITM"], "Pedro":[23, "Lopez", "Pascual Bravo"]}
estudiantes2 = estudiantes.copy()

estudiantes["Andres"] = [30,'Castro','ITM']
estudiantes["Esteban"] = [39,'Gonzalez','UNAL']
estudiantes["Juan"] = [44,'Vanegas','Colegio Mayor','1234']

print(estudiantes)
# Out:
# {'Juan': [44, 'Vanegas', 'Colegio Mayor', '1234'], 'Pedro': [23, 'Lopez', 'Pascual Bravo'], 'Andres': [30, 'Castro', 'ITM'], 'Esteban': [39, 'Gonzalez', 'UNAL']}

# %% [markdown]
# Explicar que pasa con la variable `estudiantes2`

# %%
print(estudiantes2)
# Out:
# {'Juan': [22, 'Casas', 'ITM'], 'Pedro': [23, 'Lopez', 'Pascual Bravo']}

# %%
estudiantes2.update(estudiantes)
print(estudiantes2)
# Out:
# {'Juan': [44, 'Vanegas', 'Colegio Mayor', '1234'], 'Pedro': [23, 'Lopez', 'Pascual Bravo'], 'Andres': [30, 'Castro', 'ITM'], 'Esteban': [39, 'Gonzalez', 'UNAL']}

# %% [markdown]
# Explicar que pasa con la variable `estudiantes`

# %%
k,v = estudiantes.popitem()
print(k,v)
print(estudiantes)
# Out:
# Esteban [39, 'Gonzalez', 'UNAL']
# {'Juan': [44, 'Vanegas', 'Colegio Mayor', '1234'], 'Pedro': [23, 'Lopez', 'Pascual Bravo'], 'Andres': [30, 'Castro', 'ITM']}

# %% [markdown]
# ## Iterar Diccionarios

# %%
# Iterando sobre llaves y valores a la vez
for k,v in estudiantes2.items():
    print(f"La llave: {k} tiene valor {v}")
# Out:
# La llave: Juan tiene valor [44, 'Vanegas', 'Colegio Mayor', '1234']
# La llave: Pedro tiene valor [23, 'Lopez', 'Pascual Bravo']
# La llave: Andres tiene valor [30, 'Castro', 'ITM']
# La llave: Esteban tiene valor [39, 'Gonzalez', 'UNAL']

# %%
# Iterando sobre las llaves
for key in estudiantes2.keys():
#     print(key)
    print(f"Llave: {key}, tiene valor: {estudiantes2[key]}")
# Out:
# Llave: Juan, tiene valor: [44, 'Vanegas', 'Colegio Mayor', '1234']
# Llave: Pedro, tiene valor: [23, 'Lopez', 'Pascual Bravo']
# Llave: Andres, tiene valor: [30, 'Castro', 'ITM']
# Llave: Esteban, tiene valor: [39, 'Gonzalez', 'UNAL']

# %%
# Iterando sobre los valores
for v in estudiantes2.values():
    print(v)
# Out:
# [44, 'Vanegas', 'Colegio Mayor', '1234']
# [23, 'Lopez', 'Pascual Bravo']
# [30, 'Castro', 'ITM']
# [39, 'Gonzalez', 'UNAL']

# %% [markdown]
# ##  Llenando un diccionario
#
# Primero recordemos la sintaxis como se ingresan nuevos valores a un diccionario:

# %%
estudiantes = {"Juan":[22, "Casas", "ITM"], "Pedro":[23, "Lopez", "Pascual Bravo"]}
print(estudiantes)

# Diccionario['Nueva Llave'] = Nuevo Valor
# estudiantes["Andres"] = [30,'Castro','ITM']
estudiantes[10] = 100
print(estudiantes)
# Out:
# {'Juan': [22, 'Casas', 'ITM'], 'Pedro': [23, 'Lopez', 'Pascual Bravo']}
# {'Juan': [22, 'Casas', 'ITM'], 'Pedro': [23, 'Lopez', 'Pascual Bravo'], 10: 100}

# %% [markdown]
# Analicemos el siguiente ejemplo

# %%
import math
tabla_factorial = {} #diccionario vacio
print(tabla_factorial)
type(tabla_factorial)
# Out:
# {}
# dict

# %%
for i in range(15):
    tabla_factorial[i] = math.factorial(i)

print(tabla_factorial)
# Out:
# {0: 1, 1: 1, 2: 2, 3: 6, 4: 24, 5: 120, 6: 720, 7: 5040, 8: 40320, 9: 362880, 10: 3628800, 11: 39916800, 12: 479001600, 13: 6227020800, 14: 87178291200}

# %%
print(tabla_factorial[8])
# Out:
# 40320

# %% [markdown]
# * Ahora podemos recorrer el diccionario que acabamos de armar

# %%
for key, valor in tabla_factorial.items():
    print(f"factorial de {key} es {valor}")
# Out:
# factorial de 0 es 1
# factorial de 1 es 1
# factorial de 2 es 2
# factorial de 3 es 6
# factorial de 4 es 24
# factorial de 5 es 120
# factorial de 6 es 720
# factorial de 7 es 5040
# factorial de 8 es 40320
# factorial de 9 es 362880
# factorial de 10 es 3628800
# factorial de 11 es 39916800
# factorial de 12 es 479001600
# factorial de 13 es 6227020800
# factorial de 14 es 87178291200

# %% [markdown]
# ## Ejercicios
#
#
# 1. Estime el promedio de todos los valores numericos (flotantes y enteros) en un diccionario

# %%
D5 = {'elem1': 500.0, 'elem2': 1200.0, 'elem3': 700.0, 'elem4': 800.0, 'elem5':200,
     "elem6": 'hola', "elem7":200}
print(D5)

suma = 0
cont = 0

for i in D5.values():
  if type(i)==int or type(i)==float:
    suma += i
    cont += 1

print(suma)
print(cont)

print(f"Promedio={suma/cont}")
# Out:
# {'elem1': 500.0, 'elem2': 1200.0, 'elem3': 700.0, 'elem4': 800.0, 'elem5': 200, 'elem6': 'hola', 'elem7': 200}
# 3600.0
# 6
# Promedio=600.0

# %% [markdown]
# 2. Actualice los valores numericos de un diccionario reduciendo un 25% de cada valor

# %%
#Actualice los valores de un diccionario reduciendo un 25% de cada valor que sea numérico
D5 = {'elem1': 500, 'elem2': 1200, 'elem3': 700, 'elem4': 800, 'elem5':200,
      'elem6':'hola!', 'elem7':250.5}

for llave,valor in D5.items():
  # Llenar codigo aqui
  if type(valor)==int or type(valor)==float:
    D5.update({llave:valor*0.75})

print(D5)
# Out:
# {'elem1': 375.0, 'elem2': 900.0, 'elem3': 525.0, 'elem4': 600.0, 'elem5': 150.0, 'elem6': 'hola!', 'elem7': 187.875}
